# %%
import requests
from dotenv import dotenv_values

# %%
class API_Loader:
    def __init__(self, access_token, client_secret, client_id, refresh_token):
        self.access_token = 'd8e5b3cdabb20065ea428868b776d7badb6f9331'
        self.client_secret = client_secret
        self.client_id = client_id
        self.refresh_token = refresh_token

    def _get_headers(self):
        """

        :return:
        """
        return {'Authorization': f'Bearer {self.access_token}'}

    def refresh_access_token(self):
        """
        Rafraîchit le token d'accès à chaque appel.
        """
        url = "https://www.strava.com/api/v3/oauth/token"
        payload = {
            "client_id": self.client_id,
            "client_secret": self.client_secret,
            "grant_type": "refresh_token",
            "refresh_token": self.refresh_token
        }
        response = requests.post(url, data=payload)
        if response.status_code == 200:
            token_data = response.json()
            self.access_token = token_data.get("access_token")
            print("Jeton rafraîchi avec succès.")
            return True
        else:
            print("Erreur lors du rafraîchissement du token :", response.status_code, response.text)
            return False

    def get_athlete_data(self):
        """
        Récupère les informations de l'athlète connecté.
        Rafraîchit le token à chaque appel.
        """
        if not self.refresh_access_token():
            print("Impossible de rafraîchir le token.")
            return None

        url = "https://www.strava.com/api/v3/athlete"
        response = requests.get(url, headers=self._get_headers())

        if response.status_code == 200:
            return response.json()
        else:
            print("Erreur lors de la requête :", response.status_code, response.text)
            return None

    def get_recent_activities(self, after=1735691212):
        """
        Récupère la liste des activités récentes de l'athlète connecté.

        Args:
            page (int): Le numéro de page à récupérer (utile pour la pagination).
            per_page (int): Le nombre d'activités par page.

        Returns:
            list: Une liste de dicts contenant les informations de chaque activité.
        """
        # Rafraîchit le token à chaque appel
        if not self.refresh_access_token():
            print("Impossible de rafraîchir le token.")
            return None

        url = "https://www.strava.com/api/v3/athlete/activities"
        params = {
            'after': after
        }
        response = requests.get(url, headers=self._get_headers(), params=params)
        if response.status_code == 200:
            return response.json()
        else:
            print("Erreur lors de la récupération des activités :", response.status_code, response.text)
            return None

# %%
secrets = dotenv_values('.env')

# %%
api = API_Loader(
    access_token=None,
    client_secret=secrets['STRAVA_SECRET'],
    client_id=secrets['STRAVA_CLIENT_ID'],
    refresh_token=secrets['STRAVA_REFRESH_TOKEN']
)

# %%
api.get_recent_activities()
# Out:
# Jeton rafraîchi avec succès.
# Erreur lors de la récupération des activités : 401 {"message":"Authorization Error","errors":[{"resource":"AccessToken","field":"activity:read_permission","code":"missing"}]}

# %%
api.get_athlete_data()
# Out:
# Jeton rafraîchi avec succès.
# {'id': 86360204,
#  'username': 'elancelle',
#  'resource_state': 2,
#  'firstname': 'Etienne',
#  'lastname': 'Lancelle',
#  'bio': '➡️ Semi-marathon de Paris (09/03)  \n10K (x4) : 54’54’’  \n21K (x3) : 1:59’00’’  \n42K : ?',
#  'city': 'Boulogne-Billancourt',
#  'state': None,
#  'country': None,
#  'sex': 'M',
#  'premium': False,
#  'summit': False,
#  'created_at': '2021-05-31T15:22:52Z',
#  'updated_at': '2025-02-02T15:21:04Z',
#  'badge_type_id': 0,
#  'weight': 65.0,
#  'profile_medium': 'https://dgalywyr863hv.cloudfront.net/pictures/athletes/86360204/33884293/1/medium.jpg',
#  'profile': 'https://dgalywyr863hv.cloudfront.net/pictures/athletes/86360204/33884293/1/large.jpg',
#  'friend': None,
#  'follower': None}

# %%
client_id = secrets['STRAVA_CLIENT_ID']
redirect_uri = "http://localhost:5000/callback"  # Assure-toi que cette URL est enregistrée dans ton application Strava
# Demande de tous les scopes. Selon la doc, ils doivent être séparés par des virgules.
scope = "profile:read_all,activity:read_all"

auth_url = (
    f"https://www.strava.com/oauth/authorize?"
    f"client_id={client_id}&"
    f"redirect_uri={redirect_uri}&"
    f"response_type=code&"
    f"approval_prompt=force&"
    f"scope={scope}"
)

print("Ouvre cette URL dans ton navigateur pour autoriser l'application :")
print(auth_url)
# Out:
# Ouvre cette URL dans ton navigateur pour autoriser l'application :
# https://www.strava.com/oauth/authorize?client_id=127031&redirect_uri=http://localhost:5000/callback&response_type=code&approval_prompt=force&scope=profile:read_all,activity:read_all

# %%
url = "https://www.strava.com/api/v3/oauth/token"
data = {
    'client_id': '127031',
    'client_secret': '641f9f581fc9ce96833f6d863361f447fd2e2ac0',
    'grant_type': 'refresh_token',
    'refresh_token': '0125eaf0ccf6a09cb538eccfea341e9219206a2e'
}
response = requests.post(url, data=data, timeout=20).json()

# %%
response
# Out:
# {'token_type': 'Bearer',
#  'access_token': 'd8e5b3cdabb20065ea428868b776d7badb6f9331',
#  'expires_at': 1739645717,
#  'expires_in': 20661,
#  'refresh_token': '0125eaf0ccf6a09cb538eccfea341e9219206a2e'}

# %%
https://www.strava.com/oauth/authorize?client_id=127031&redirect_uri=http://localhost:5000/callback&response_type=code&scope=activity:read_all

# %%
http://localhost:5000/callback?state=&code=1f9bafa1ec95e60a1e6b84a88b190bd91d5c1c64&scope=read,activity:read_all

# %%
https://www.strava.com/oauth/authorize?client_id=127031&redirect_uri=http://localhost:5000/callback&response_type=code&scope=activity:read_all&approval_prompt=force

# %%
http://localhost:5000/callback?state=&code=5f7916556cf3954463e7079dda38f8466f31f8df&scope=read,activity:read_all

# %%
import requests

# Remplace par tes infos
CLIENT_ID = "127031"
CLIENT_SECRET = "641f9f581fc9ce96833f6d863361f447fd2e2ac0"
CODE = "2f45e57ede72d174e9dc2172ebcc6b28d8ad1f22"  # Remplace avec le code obtenu à l'étape 1

# Échange du code contre un token d'accès
url = "https://www.strava.com/oauth/token"
params = {
    "client_id": CLIENT_ID,
    "client_secret": CLIENT_SECRET,
    "code": CODE,
    "grant_type": "authorization_code",
}

response = requests.post(url, data=params)
tokens = response.json()

if "access_token" in tokens:
    print("✅ Jeton d'accès récupéré avec succès !")
    print("Access Token:", tokens["access_token"])
    print("Refresh Token:", tokens["refresh_token"])
    print("Expire dans:", tokens["expires_in"], "secondes")
else:
    print("❌ Erreur :", tokens)
# Out:
# ✅ Jeton d'accès récupéré avec succès !
# Access Token: 79f3c343cf1dd482f3843540649416ebb4bf70cd
# Refresh Token: e4c6dab4ad00d26aaf19712d22a1006210ac3ef2
# Expire dans: 8632 secondes

# %%
import requests

REFRESH_TOKEN = "e4c6dab4ad00d26aaf19712d22a1006210ac3ef2"  # À récupérer depuis l'étape 2

def refresh_token():
    url = "https://www.strava.com/oauth/token"
    params = {
        "client_id": CLIENT_ID,
        "client_secret": CLIENT_SECRET,
        "refresh_token": REFRESH_TOKEN,
        "grant_type": "refresh_token",
    }

    response = requests.post(url, data=params)
    tokens = response.json()

    if "access_token" in tokens:
        print("✅ Nouveau jeton d'accès récupéré !")
        print("Access Token:", tokens["access_token"])
        print("Refresh Token:", tokens["refresh_token"])
        return tokens["access_token"], tokens["refresh_token"]
    else:
        print("❌ Erreur :", tokens)
        return None, None

# Utilisation
access_token, refresh_token = refresh_token()
# Out:
# ✅ Nouveau jeton d'accès récupéré !
# Access Token: 79f3c343cf1dd482f3843540649416ebb4bf70cd
# Refresh Token: e4c6dab4ad00d26aaf19712d22a1006210ac3ef2

# %%
ACCESS_TOKEN = "79f3c343cf1dd482f3843540649416ebb4bf70cd"

url = "https://www.strava.com/api/v3/athlete/activities"
headers = {"Authorization": f"Bearer {ACCESS_TOKEN}"}
params = {"per_page": 50}  # Nombre d'activités à récupérer

response = requests.get(url, headers=headers, params=params)

if response.status_code == 200:
    activities = response.json()
    for i, act in enumerate(activities, 1):
        print(f"{i}. {act['name']} - {act['distance']}m")
else:
    print("❌ Erreur :", response.json())
# Out:
# 1. 🗼 Lunch Run (🧡 J-22 & 🗼 J-57) - 4796.5m
# 2. 🗼 SL 100% plaisir sous le soleil (🧡 J-23 & 🗼 J-58) - 11450.7m
# 3. 🗼 Lunch Run (🧡 J-24 & 🗼 J-59) - 5570.1m
# 4. 🗼 Evening Run 🏃🏻‍♂️🏃🏻‍♀️ (🧡 J-25 & 🗼 J-60) - 6728.0m
# 5. 🗼 Un petit tour ! (🧡 J-26 & 🗼 J-61) - 3783.5m
# 6. 🗼 Mini-run : croquettes pour chat à aller chercher ! (🧡 J-27 & 🗼 J-62) - 2695.7m
# 7. 🗼 Domaine St-Cloud ⚜️ (🧡 J-28 & 🗼 J-63) - 10402.9m
# 8. 🗼 Evening Run (🧡 J-29 & 🗼 J-64) - 4097.2m
# 9. 🗼 La Spirale 🌀 🏃🏻‍♂️🏃🏻‍♀️ (🧡 J-30 & 🗼 J-65) - 16111.3m
# 10. 🗼 Afternoon Run (🧡 J-31 & 🗼 J-66) - 3934.9m
# 11. 🗼 Fractionné du déjeuner 🥵 (🧡 J-32 & 🗼 J-67) - 9992.9m
# 12. 🗼 EF 45’ 🧊 🏃🏻‍♂️🏃🏻‍♀️ (🧡 J-33 & 🗼 J-68) - 6366.2m
# 13. 🗼 Evening Run 🏃🏻‍♂️🏃🏻‍♀️ (🧡 J-34 & 🗼 J-69) - 6532.7m
# 14. 🗼 SL 1h40 ☀️ (🧡 J-35 & 🗼 J-70) - 15651.0m
# 15. 🗼 Night Run (🧡 J-36 & 🗼 J-71) - 4196.5m
# 16. 🚶🏻‍♂️ La balade sous le soleil ☀️ ft. Enora 🌸 - 6468.5m
# 17. 🗼 Evening Run (🧡 J-37 & 🗼 J-72) - 6068.1m
# 18. 🗼 Night Run (🧡 J-38 & 🗼 J-73) - 4138.6m
# 19. 🗼 Variations d’allures 🚀 (🧡 J-39 & 🗼 J-74) - 8332.7m
# 20. 🗼 EF 40’ (🧡 J-40 & 🗼 J-75) - 6129.5m
# 21. 🗼 Evening Run (🧡 J-41 & 🗼 J-76) - 3675.6m
# 22. 🗼 Night Run (🧡 J-42 & 🗼 J-77) - 4152.4m
# 23. 🗼 EF 1h30 💫 (🧡 J-43 & 🗼 J-78) - 14090.0m
# 24. 🗼 5 x 4’ @5’25 🥵🥵🥵 🏃🏻‍♂️🏃🏻‍♀️ (🧡 J-44 & 🗼 J-79) - 7725.5m
# 25. 🗼 Tous les jours c’est tous les jours ! (🧡 J-45 & 🗼 J-80) - 4114.4m
# 26. 🗼 Régularité… (averse constante) (🧡 J-46 & 🗼 J-81) - 2166.9m
# 27. 🗼 Variations d’allures ⚡️ 🏃🏻‍♂️🏃🏻‍♀️ (🧡 J-47 & 🗼 J-82) - 7204.2m
# 28. 🗼 EF 40’ 🏃🏻‍♂️🏃🏻‍♀️ (🧡 J-48 & 🗼 J-83) - 5778.5m
# 29. 🗼 Night Run (🧡 J-49 & 🗼 J-84) - 4097.7m
# 30. 🗼 EF 1h 🔄 (🧡 J-50 & 🗼 J-85) - 8718.5m
# 31. 🗼 Un peu de vitesse ⚡️ 🏃🏻‍♂️🏃🏻‍♀️ (🧡 J-51 & 🗼 J-86) - 6587.0m
# 32. 🗼 Tour des Tuileries 🔁 (🧡 J-52 & 🗼 J-87) - 4015.2m
# 33. 🗼 Night Run 🌙 (🧡 J-53 & 🗼 J-88) - 4059.5m
# 34. 🗼 6 lignes droites 🚀 🏃🏻‍♂️🏃🏻‍♀️ (🧡 J-54 & 🗼 J-89) - 4421.1m
# 35. 🗼 Evening Run 🏃🏻‍♂️🏃🏻‍♀️ (🧡 J-55 & 🗼 J-90) - 4135.9m
# 36. 🗼 Petit run de fin de week-end entre copaings (🧡 J-56 & 🗼 J-91) - 3951.6m
# 37. 🗼 Morning Run (🧡 J-57 & 🗼 J-92) - 3685.5m
# 38. 🗼 SL 1h15 🫶🏻🍔 🏃🏻‍♂️🏃🏻‍♀️ (🧡 J-58 & 🗼 J-93) - 10796.5m
# 39. 🗼 4 x 4’ @5’10 🥵🥶 (🧡 J-59 & 🗼 J-94) - 8927.1m
# 40. 🗼 6 x 3’ @5’20 ☔️🐸 (🧡 J-60 & 🗼 J-95) - 8108.6m
# 41. 🗼 EF 45’ 🏠 🏃🏻‍♂️🏃🏻‍♀️ (🧡 J-61 & 🗼 J-96) - 6270.8m
# 42. 🗼 Evening Run (🧡 J-62 & 🗼 J-97) - 3799.4m
# 43. 🗼 Le poti tour 💫 (🧡 J-63 & 🗼 J-98) - 3768.7m
# 44. 🗼 4 x 3’ @5’11 🥶⚡️ 🏃🏻‍♂️🏃🏻‍♀️ (🧡 J-64 & 🗼 J-99) - 7808.2m
# 45. 🗼 SL 1h30 ❤️ 🏃🏻‍♂️🏃🏻‍♀️ (🧡 J-65 & 🗼 J-100) - 13304.4m
# 46. 🗼 EF 35’ + 6 lignes droites 💨 (🧡 J-66 & 🗼 J-101) - 7123.0m
# 47. 🗼 Footing 45’ 🥶 🏃🏻‍♂️🏃🏻‍♀️ (🧡 J-67 & 🗼 J-102) - 6698.6m
# 48. 🏃🏻‍♂️ SL 1h20 🥶 - 12388.8m
# 49. 🚶🏻‍♂️ Promenade 🚶‍♂️ - 4313.2m
# 50. 🏃🏻‍♂️ Seuil 30 : 5 x 2’ @5’10 🥵 - 5782.3m

# %%
activities[3]
# Out:
# {'resource_state': 2,
#  'athlete': {'id': 86360204, 'resource_state': 1},
#  'name': '🗼 Evening Run 🏃🏻\u200d♂️🏃🏻\u200d♀️ (🧡 J-25 & 🗼 J-60)',
#  'distance': 6728.0,
#  'moving_time': 2420,
#  'elapsed_time': 2445,
#  'total_elevation_gain': 22.0,
#  'type': 'Run',
#  'sport_type': 'Run',
#  'workout_type': None,
#  'id': 13610646858,
#  'start_date': '2025-02-12T18:01:31Z',
#  'start_date_local': '2025-02-12T19:01:31Z',
#  'timezone': '(GMT+01:00) Europe/Paris',
#  'utc_offset': 3600.0,
#  'location_city': None,
#  'location_state': None,
#  'location_country': None,
#  'achievement_count': 3,
#  'kudos_count': 20,
#  'comment_count': 0,
#  'athlete_count': 2,
#  'photo_count': 0,
#  'map': {'id': 'a13610646858',
#   'summary_polyline': 'mo_iHq}tLIa@@S`@eB^kCLk@x@uBHu@^yAPyA`@{AJy@jAeEPkADKLIHAJDFEPc@D[DKDCPCvB}@p@_@n@QbAe@PEJBFA^Y^UfBu@B?x@[ZQLDHNTDHBb@r@Z~@Ab@Fn@bAnFJx@R`A@NK^?TNz@l@zEd@vFLhDAjACb@Ar@?z@HrBBpCG|CKbBE^Ov@_@xCc@lBcAhGYvBUlAU|@CX]rB_@lBqAhEER?PCLQf@GVa@nAm@dBMj@Qh@Yh@M\\mCrDq@p@kAxASPR[t@w@nBcCz@mANOPYRg@Nq@D?f@sAr@yBXgA\\w@Nw@hBsFh@uBNQP_@PsAn@cDVuBb@kF^_DB{@Hi@LoBJ{CA_DMwDHsAAcAKwBA}@MqBIm@QoBGg@Lr@b@jEJrBDxC?j@El@?|@HfCAlABv@?~Aa@tFq@lE{@tEk@lDIz@Mn@Kv@Mb@OhAk@xCi@lBo@hBYn@y@zASn@QX_BnDw@tAKTATOZs@o@aAiAuAuBGOYUOUk@m@k@{@aBoB_EqEACBk@AEc@i@UQOc@Ci@NiA`@mANm@JSNg@P]P_Al@iB|@kD?IGQNoATu@Jo@t@wBMq@a@k@',
#   'resource_state': 2},
#  'trainer': False,
#  'commute': False,
#  'manual': False,
#  'private': False,
#  'visibility': 'followers_only',
#  'flagged': False,
#  'gear_id': 'g20035175',
#  'start_latlng': [48.825737, 2.2401],
#  'end_latlng': [48.827179, 2.241363],
#  'average_speed': 2.78,
#  'max_speed': 4.02,
#  'average_cadence': 87.3,
#  'average_temp': 22,
#  'average_watts': 250.4,
#  'max_watts': 429,
#  'weighted_average_watts': 249,
#  'device_watts': True,
#  'kilojoules': 606.2,
#  'has_heartrate': True,
#  'average_heartrate': 152.2,
#  'max_heartrate': 173.0,
#  'heartrate_opt_out': False,
#  'display_hide_heartrate_option': True,
#  'elev_high': 37.6,
#  'elev_low': 27.4,
#  'upload_id': 14522249842,
#  'upload_id_str': '14522249842',
#  'external_id': 'garmin_ping_410501272887',
#  'from_accepted_tag': False,
#  'pr_count': 0,
#  'total_photo_count': 0,
#  'has_kudoed': False}

# %%
ACCESS_TOKEN = "79f3c343cf1dd482f3843540649416ebb4bf70cd"

url = "https://www.strava.com/api/v3/activities/13610646858"
headers = {"Authorization": f"Bearer {ACCESS_TOKEN}"}
params = {}  # Nombre d'activités à récupérer

response = requests.get(url, headers=headers, params=params)

if response.status_code == 200:
    activities = response.json()
    for i, act in enumerate(activities, 1):
        print(f"{i}. {act['name']} - {act['distance']}m")
else:
    print("❌ Erreur :", response.json())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[86], line 12
#      10     activities = response.json()
#      11     for i, act in enumerate(activities, 1):
# ---> 12         print(f"{i}. {act['name']} - {act['distance']}m")
#      13 else:
#      14     print("❌ Erreur :", response.json())
#
# TypeError: string indices must be integers, not 'str'

# %%
act = response.json()

# %%
import pprint

# %%
pprint.pprint(act)
# Out:
# {'achievement_count': 3,
#  'athlete': {'id': 86360204, 'resource_state': 1},
#  'athlete_count': 2,
#  'available_zones': [],
#  'average_cadence': 87.3,
#  'average_heartrate': 152.2,
#  'average_speed': 2.78,
#  'average_temp': 22,
#  'average_watts': 250.4,
#  'best_efforts': [{'achievements': [],
#                    'activity': {'id': 13610646858,
#                                 'resource_state': 1,
#                                 'visibility': 'followers_only'},
#                    'athlete': {'id': 86360204, 'resource_state': 1},
#                    'distance': 400,
#                    'elapsed_time': 130,
#                    'end_index': 1826,
#                    'id': 57566494690,
#                    'moving_time': 130,
#                    'name': '400m',
#                    'pr_rank': None,
#                    'resource_state': 2,
#                    'start_date': '2025-02-12T18:01:31Z',
#                    'start_date_local': '2025-02-12T19:01:31Z',
#                    'start_index': 1696},
#                   {'achievements': [],
#                    'activity': {'id': 13610646858,
#                                 'resource_state': 1,
#                                 'visibility': 'followers_only'},
#                    'athlete': {'id': 86360204, 'resource_state': 1},
#                    'distance': 805,
#                    'elapsed_time': 263,
#                    'end_index': 1836,
#                    'id': 57566494691,
#                    'moving_time': 263,
#                    'name': '1/2 mile',
#                    'pr_rank': None,
#                    'resource_state': 2,
#                    'start_date': '2025-02-12T18:01:31Z',
#                    'start_date_local': '2025-02-12T19:01:31Z',
#                    'start_index': 1573},
#                   {'achievements': [],
#                    'activity': {'id': 13610646858,
#                                 'resource_state': 1,
#                                 'visibility': 'followers_only'},
#                    'athlete': {'id': 86360204, 'resource_state': 1},
#                    'distance': 1000,
#                    'elapsed_time': 327,
#                    'end_index': 1886,
#                    'id': 57566494692,
#                    'moving_time': 327,
#                    'name': '1K',
#                    'pr_rank': None,
#                    'resource_state': 2,
#                    'start_date': '2025-02-12T18:01:31Z',
#                    'start_date_local': '2025-02-12T19:01:31Z',
#                    'start_index': 1559},
#                   {'achievements': [],
#                    'activity': {'id': 13610646858,
#                                 'resource_state': 1,
#                                 'visibility': 'followers_only'},
#                    'athlete': {'id': 86360204, 'resource_state': 1},
#                    'distance': 1609,
#                    'elapsed_time': 535,
#                    'end_index': 1864,
#                    'id': 57566494687,
#                    'moving_time': 535,
#                    'name': '1 mile',
#                    'pr_rank': None,
#                    'resource_state': 2,
#                    'start_date': '2025-02-12T18:01:31Z',
#                    'start_date_local': '2025-02-12T19:01:31Z',
#                    'start_index': 1329},
#                   {'achievements': [],
#                    'activity': {'id': 13610646858,
#                                 'resource_state': 1,
#                                 'visibility': 'followers_only'},
#                    'athlete': {'id': 86360204, 'resource_state': 1},
#                    'distance': 3219,
#                    'elapsed_time': 1097,
#                    'end_index': 1961,
#                    'id': 57566494688,
#                    'moving_time': 1097,
#                    'name': '2 mile',
#                    'pr_rank': None,
#                    'resource_state': 2,
#                    'start_date': '2025-02-12T18:01:31Z',
#                    'start_date_local': '2025-02-12T19:01:31Z',
#                    'start_index': 864},
#                   {'achievements': [],
#                    'activity': {'id': 13610646858,
#                                 'resource_state': 1,
#                                 'visibility': 'followers_only'},
#                    'athlete': {'id': 86360204, 'resource_state': 1},
#                    'distance': 5000,
#                    'elapsed_time': 1773,
#                    'end_index': 2123,
#                    'id': 57566494689,
#                    'moving_time': 1773,
#                    'name': '5K',
#                    'pr_rank': None,
#                    'resource_state': 2,
#                    'start_date': '2025-02-12T18:01:31Z',
#                    'start_date_local': '2025-02-12T19:01:31Z',
#                    'start_index': 350}],
#  'calories': 453.0,
#  'comment_count': 0,
#  'commute': False,
#  'description': None,
#  'device_name': 'Garmin Forerunner 965',
#  'device_watts': True,
#  'display_hide_heartrate_option': True,
#  'distance': 6728.0,
#  'elapsed_time': 2445,
#  'elev_high': 37.6,
#  'elev_low': 27.4,
#  'embed_token': '2785ece2f5a7984255b87d8bea7abc6b35f46a3b',
#  'end_latlng': [48.827179, 2.241363],
#  'external_id': 'garmin_ping_410501272887',
#  'flagged': False,
#  'from_accepted_tag': False,
#  'gear': {'converted_distance': 496.2,
#           'distance': 496152,
#           'id': 'g20035175',
#           'name': 'New Balance Fresh Foam X 1080 v14',
#           'nickname': None,
#           'primary': False,
#           'resource_state': 2,
#           'retired': False},
#  'gear_id': 'g20035175',
#  'has_heartrate': True,
#  'has_kudoed': False,
#  'heartrate_opt_out': False,
#  'hide_from_home': False,
#  'id': 13610646858,
#  'kilojoules': 606.2,
#  'kudos_count': 20,
#  'laps': [{'activity': {'id': 13610646858,
#                         'resource_state': 1,
#                         'visibility': 'followers_only'},
#            'athlete': {'id': 86360204, 'resource_state': 1},
#            'average_cadence': 87.0,
#            'average_heartrate': 134.8,
#            'average_speed': 2.67,
#            'average_watts': 247.0,
#            'device_watts': True,
#            'distance': 1000.0,
#            'elapsed_time': 400,
#            'end_index': 271,
#            'id': 48118478673,
#            'lap_index': 1,
#            'max_heartrate': 150.0,
#            'max_speed': 3.62,
#            'moving_time': 375,
#            'name': 'Lap 1',
#            'pace_zone': 2,
#            'resource_state': 2,
#            'split': 1,
#            'start_date': '2025-02-12T18:01:31Z',
#            'start_date_local': '2025-02-12T19:01:31Z',
#            'start_index': 0,
#            'total_elevation_gain': 7.4},
#           {'activity': {'id': 13610646858,
#                         'resource_state': 1,
#                         'visibility': 'followers_only'},
#            'athlete': {'id': 86360204, 'resource_state': 1},
#            'average_cadence': 87.3,
#            'average_heartrate': 143.8,
#            'average_speed': 2.7,
#            'average_watts': 236.8,
#            'device_watts': True,
#            'distance': 1000.0,
#            'elapsed_time': 371,
#            'end_index': 643,
#            'id': 48118478683,
#            'lap_index': 2,
#            'max_heartrate': 152.0,
#            'max_speed': 3.24,
#            'moving_time': 371,
#            'name': 'Lap 2',
#            'pace_zone': 3,
#            'resource_state': 2,
#            'split': 2,
#            'start_date': '2025-02-12T18:08:13Z',
#            'start_date_local': '2025-02-12T19:08:13Z',
#            'start_index': 272,
#            'total_elevation_gain': 0.0},
#           {'activity': {'id': 13610646858,
#                         'resource_state': 1,
#                         'visibility': 'followers_only'},
#            'athlete': {'id': 86360204, 'resource_state': 1},
#            'average_cadence': 87.2,
#            'average_heartrate': 146.2,
#            'average_speed': 2.64,
#            'average_watts': 245.9,
#            'device_watts': True,
#            'distance': 595.01,
#            'elapsed_time': 224,
#            'end_index': 867,
#            'id': 48118478686,
#            'lap_index': 3,
#            'max_heartrate': 152.0,
#            'max_speed': 3.32,
#            'moving_time': 225,
#            'name': 'Lap 3',
#            'pace_zone': 2,
#            'resource_state': 2,
#            'split': 3,
#            'start_date': '2025-02-12T18:14:25Z',
#            'start_date_local': '2025-02-12T19:14:25Z',
#            'start_index': 644,
#            'total_elevation_gain': 4.2},
#           {'activity': {'id': 13610646858,
#                         'resource_state': 1,
#                         'visibility': 'followers_only'},
#            'athlete': {'id': 86360204, 'resource_state': 1},
#            'average_cadence': 89.8,
#            'average_heartrate': 165.3,
#            'average_speed': 3.43,
#            'average_watts': 289.4,
#            'device_watts': True,
#            'distance': 206.08,
#            'elapsed_time': 60,
#            'end_index': 927,
#            'id': 48118478688,
#            'lap_index': 4,
#            'max_heartrate': 173.0,
#            'max_speed': 4.0,
#            'moving_time': 60,
#            'name': 'Lap 4',
#            'pace_zone': 6,
#            'resource_state': 2,
#            'split': 4,
#            'start_date': '2025-02-12T18:18:09Z',
#            'start_date_local': '2025-02-12T19:18:09Z',
#            'start_index': 868,
#            'total_elevation_gain': 0.0},
#           {'activity': {'id': 13610646858,
#                         'resource_state': 1,
#                         'visibility': 'followers_only'},
#            'athlete': {'id': 86360204, 'resource_state': 1},
#            'average_cadence': 86.0,
#            'average_heartrate': 160.8,
#            'average_speed': 2.56,
#            'average_watts': 224.0,
#            'device_watts': True,
#            'distance': 153.3,
#            'elapsed_time': 60,
#            'end_index': 987,
#            'id': 48118478690,
#            'lap_index': 5,
#            'max_heartrate': 171.0,
#            'max_speed': 3.2,
#            'moving_time': 60,
#            'name': 'Lap 5',
#            'pace_zone': 2,
#            'resource_state': 2,
#            'split': 5,
#            'start_date': '2025-02-12T18:19:09Z',
#            'start_date_local': '2025-02-12T19:19:09Z',
#            'start_index': 928,
#            'total_elevation_gain': 0.0},
#           {'activity': {'id': 13610646858,
#                         'resource_state': 1,
#                         'visibility': 'followers_only'},
#            'athlete': {'id': 86360204, 'resource_state': 1},
#            'average_cadence': 88.4,
#            'average_heartrate': 163.7,
#            'average_speed': 3.3,
#            'average_watts': 278.1,
#            'device_watts': True,
#            'distance': 198.13,
#            'elapsed_time': 60,
#            'end_index': 1047,
#            'id': 48118478691,
#            'lap_index': 6,
#            'max_heartrate': 167.0,
#            'max_speed': 3.62,
#            'moving_time': 60,
#            'name': 'Lap 6',
#            'pace_zone': 5,
#            'resource_state': 2,
#            'split': 6,
#            'start_date': '2025-02-12T18:20:09Z',
#            'start_date_local': '2025-02-12T19:20:09Z',
#            'start_index': 988,
#            'total_elevation_gain': 0.0},
#           {'activity': {'id': 13610646858,
#                         'resource_state': 1,
#                         'visibility': 'followers_only'},
#            'athlete': {'id': 86360204, 'resource_state': 1},
#            'average_cadence': 86.3,
#            'average_heartrate': 160.2,
#            'average_speed': 2.59,
#            'average_watts': 252.4,
#            'device_watts': True,
#            'distance': 155.66,
#            'elapsed_time': 60,
#            'end_index': 1107,
#            'id': 48118478693,
#            'lap_index': 7,
#            'max_heartrate': 167.0,
#            'max_speed': 3.12,
#            'moving_time': 60,
#            'name': 'Lap 7',
#            'pace_zone': 2,
#            'resource_state': 2,
#            'split': 7,
#            'start_date': '2025-02-12T18:21:09Z',
#            'start_date_local': '2025-02-12T19:21:09Z',
#            'start_index': 1048,
#            'total_elevation_gain': 0.0},
#           {'activity': {'id': 13610646858,
#                         'resource_state': 1,
#                         'visibility': 'followers_only'},
#            'athlete': {'id': 86360204, 'resource_state': 1},
#            'average_cadence': 89.0,
#            'average_heartrate': 161.7,
#            'average_speed': 3.21,
#            'average_watts': 258.1,
#            'device_watts': True,
#            'distance': 192.52,
#            'elapsed_time': 60,
#            'end_index': 1167,
#            'id': 48118478694,
#            'lap_index': 8,
#            'max_heartrate': 164.0,
#            'max_speed': 3.56,
#            'moving_time': 60,
#            'name': 'Lap 8',
#            'pace_zone': 4,
#            'resource_state': 2,
#            'split': 8,
#            'start_date': '2025-02-12T18:22:09Z',
#            'start_date_local': '2025-02-12T19:22:09Z',
#            'start_index': 1108,
#            'total_elevation_gain': 0.0},
#           {'activity': {'id': 13610646858,
#                         'resource_state': 1,
#                         'visibility': 'followers_only'},
#            'athlete': {'id': 86360204, 'resource_state': 1},
#            'average_cadence': 86.6,
#            'average_heartrate': 159.8,
#            'average_speed': 2.68,
#            'average_watts': 256.4,
#            'device_watts': True,
#            'distance': 160.77,
#            'elapsed_time': 60,
#            'end_index': 1227,
#            'id': 48118478695,
#            'lap_index': 9,
#            'max_heartrate': 165.0,
#            'max_speed': 3.38,
#            'moving_time': 60,
#            'name': 'Lap 9',
#            'pace_zone': 2,
#            'resource_state': 2,
#            'split': 9,
#            'start_date': '2025-02-12T18:23:09Z',
#            'start_date_local': '2025-02-12T19:23:09Z',
#            'start_index': 1168,
#            'total_elevation_gain': 0.0},
#           {'activity': {'id': 13610646858,
#                         'resource_state': 1,
#                         'visibility': 'followers_only'},
#            'athlete': {'id': 86360204, 'resource_state': 1},
#            'average_cadence': 87.2,
#            'average_heartrate': 162.5,
#            'average_speed': 3.25,
#            'average_watts': 285.5,
#            'device_watts': True,
#            'distance': 195.06,
#            'elapsed_time': 60,
#            'end_index': 1287,
#            'id': 48118478697,
#            'lap_index': 10,
#            'max_heartrate': 168.0,
#            'max_speed': 3.5,
#            'moving_time': 60,
#            'name': 'Lap 10',
#            'pace_zone': 5,
#            'resource_state': 2,
#            'split': 10,
#            'start_date': '2025-02-12T18:24:09Z',
#            'start_date_local': '2025-02-12T19:24:09Z',
#            'start_index': 1228,
#            'total_elevation_gain': 0.0},
#           {'activity': {'id': 13610646858,
#                         'resource_state': 1,
#                         'visibility': 'followers_only'},
#            'athlete': {'id': 86360204, 'resource_state': 1},
#            'average_cadence': 87.4,
#            'average_heartrate': 162.0,
#            'average_speed': 2.68,
#            'average_watts': 250.3,
#            'device_watts': True,
#            'distance': 160.91,
#            'elapsed_time': 60,
#            'end_index': 1347,
#            'id': 48118478700,
#            'lap_index': 11,
#            'max_heartrate': 168.0,
#            'max_speed': 3.2,
#            'moving_time': 60,
#            'name': 'Lap 11',
#            'pace_zone': 2,
#            'resource_state': 2,
#            'split': 11,
#            'start_date': '2025-02-12T18:25:09Z',
#            'start_date_local': '2025-02-12T19:25:09Z',
#            'start_index': 1288,
#            'total_elevation_gain': 0.0},
#           {'activity': {'id': 13610646858,
#                         'resource_state': 1,
#                         'visibility': 'followers_only'},
#            'athlete': {'id': 86360204, 'resource_state': 1},
#            'average_cadence': 88.2,
#            'average_heartrate': 160.7,
#            'average_speed': 3.16,
#            'average_watts': 273.7,
#            'device_watts': True,
#            'distance': 189.65,
#            'elapsed_time': 60,
#            'end_index': 1407,
#            'id': 48118478702,
#            'lap_index': 12,
#            'max_heartrate': 167.0,
#            'max_speed': 3.7,
#            'moving_time': 60,
#            'name': 'Lap 12',
#            'pace_zone': 4,
#            'resource_state': 2,
#            'split': 12,
#            'start_date': '2025-02-12T18:26:09Z',
#            'start_date_local': '2025-02-12T19:26:09Z',
#            'start_index': 1348,
#            'total_elevation_gain': 0.0},
#           {'activity': {'id': 13610646858,
#                         'resource_state': 1,
#                         'visibility': 'followers_only'},
#            'athlete': {'id': 86360204, 'resource_state': 1},
#            'average_cadence': 86.7,
#            'average_heartrate': 158.5,
#            'average_speed': 2.57,
#            'average_watts': 251.6,
#            'device_watts': True,
#            'distance': 153.98,
#            'elapsed_time': 60,
#            'end_index': 1467,
#            'id': 48118478704,
#            'lap_index': 13,
#            'max_heartrate': 166.0,
#            'max_speed': 3.02,
#            'moving_time': 60,
#            'name': 'Lap 13',
#            'pace_zone': 2,
#            'resource_state': 2,
#            'split': 13,
#            'start_date': '2025-02-12T18:27:09Z',
#            'start_date_local': '2025-02-12T19:27:09Z',
#            'start_index': 1408,
#            'total_elevation_gain': 0.0},
#           {'activity': {'id': 13610646858,
#                         'resource_state': 1,
#                         'visibility': 'followers_only'},
#            'athlete': {'id': 86360204, 'resource_state': 1},
#            'average_cadence': 89.2,
#            'average_heartrate': 163.6,
#            'average_speed': 3.34,
#            'average_watts': 259.1,
#            'device_watts': True,
#            'distance': 200.46,
#            'elapsed_time': 60,
#            'end_index': 1527,
#            'id': 48118478707,
#            'lap_index': 14,
#            'max_heartrate': 170.0,
#            'max_speed': 3.62,
#            'moving_time': 60,
#            'name': 'Lap 14',
#            'pace_zone': 5,
#            'resource_state': 2,
#            'split': 14,
#            'start_date': '2025-02-12T18:28:09Z',
#            'start_date_local': '2025-02-12T19:28:09Z',
#            'start_index': 1468,
#            'total_elevation_gain': 0.0},
#           {'activity': {'id': 13610646858,
#                         'resource_state': 1,
#                         'visibility': 'followers_only'},
#            'athlete': {'id': 86360204, 'resource_state': 1},
#            'average_cadence': 87.6,
#            'average_heartrate': 160.2,
#            'average_speed': 2.69,
#            'average_watts': 247.0,
#            'device_watts': True,
#            'distance': 161.54,
#            'elapsed_time': 60,
#            'end_index': 1587,
#            'id': 48118478710,
#            'lap_index': 15,
#            'max_heartrate': 167.0,
#            'max_speed': 3.52,
#            'moving_time': 60,
#            'name': 'Lap 15',
#            'pace_zone': 2,
#            'resource_state': 2,
#            'split': 15,
#            'start_date': '2025-02-12T18:29:09Z',
#            'start_date_local': '2025-02-12T19:29:09Z',
#            'start_index': 1528,
#            'total_elevation_gain': 0.0},
#           {'activity': {'id': 13610646858,
#                         'resource_state': 1,
#                         'visibility': 'followers_only'},
#            'athlete': {'id': 86360204, 'resource_state': 1},
#            'average_cadence': 89.4,
#            'average_heartrate': 162.8,
#            'average_speed': 3.33,
#            'average_watts': 273.4,
#            'device_watts': True,
#            'distance': 199.52,
#            'elapsed_time': 60,
#            'end_index': 1647,
#            'id': 48118478715,
#            'lap_index': 16,
#            'max_heartrate': 168.0,
#            'max_speed': 3.66,
#            'moving_time': 60,
#            'name': 'Lap 16',
#            'pace_zone': 5,
#            'resource_state': 2,
#            'split': 16,
#            'start_date': '2025-02-12T18:30:09Z',
#            'start_date_local': '2025-02-12T19:30:09Z',
#            'start_index': 1588,
#            'total_elevation_gain': 0.0},
#           {'activity': {'id': 13610646858,
#                         'resource_state': 1,
#                         'visibility': 'followers_only'},
#            'athlete': {'id': 86360204, 'resource_state': 1},
#            'average_cadence': 87.1,
#            'average_heartrate': 163.2,
#            'average_speed': 2.79,
#            'average_watts': 259.0,
#            'device_watts': True,
#            'distance': 167.31,
#            'elapsed_time': 60,
#            'end_index': 1707,
#            'id': 48118478719,
#            'lap_index': 17,
#            'max_heartrate': 168.0,
#            'max_speed': 3.26,
#            'moving_time': 60,
#            'name': 'Lap 17',
#            'pace_zone': 3,
#            'resource_state': 2,
#            'split': 17,
#            'start_date': '2025-02-12T18:31:09Z',
#            'start_date_local': '2025-02-12T19:31:09Z',
#            'start_index': 1648,
#            'total_elevation_gain': 0.0},
#           {'activity': {'id': 13610646858,
#                         'resource_state': 1,
#                         'visibility': 'followers_only'},
#            'athlete': {'id': 86360204, 'resource_state': 1},
#            'average_cadence': 87.3,
#            'average_heartrate': 164.1,
#            'average_speed': 3.3,
#            'average_watts': 276.8,
#            'device_watts': True,
#            'distance': 197.76,
#            'elapsed_time': 60,
#            'end_index': 1767,
#            'id': 48118478724,
#            'lap_index': 18,
#            'max_heartrate': 170.0,
#            'max_speed': 4.02,
#            'moving_time': 60,
#            'name': 'Lap 18',
#            'pace_zone': 5,
#            'resource_state': 2,
#            'split': 18,
#            'start_date': '2025-02-12T18:32:09Z',
#            'start_date_local': '2025-02-12T19:32:09Z',
#            'start_index': 1708,
#            'total_elevation_gain': 0.0},
#           {'activity': {'id': 13610646858,
#                         'resource_state': 1,
#                         'visibility': 'followers_only'},
#            'athlete': {'id': 86360204, 'resource_state': 1},
#            'average_cadence': 85.8,
#            'average_heartrate': 163.4,
#            'average_speed': 2.68,
#            'average_watts': 251.7,
#            'device_watts': True,
#            'distance': 161.03,
#            'elapsed_time': 60,
#            'end_index': 1827,
#            'id': 48118478726,
#            'lap_index': 19,
#            'max_heartrate': 170.0,
#            'max_speed': 3.14,
#            'moving_time': 60,
#            'name': 'Lap 19',
#            'pace_zone': 2,
#            'resource_state': 2,
#            'split': 19,
#            'start_date': '2025-02-12T18:33:09Z',
#            'start_date_local': '2025-02-12T19:33:09Z',
#            'start_index': 1768,
#            'total_elevation_gain': 0.0},
#           {'activity': {'id': 13610646858,
#                         'resource_state': 1,
#                         'visibility': 'followers_only'},
#            'athlete': {'id': 86360204, 'resource_state': 1},
#            'average_cadence': 86.9,
#            'average_heartrate': 155.1,
#            'average_speed': 2.59,
#            'average_watts': 245.2,
#            'device_watts': True,
#            'distance': 1000.0,
#            'elapsed_time': 386,
#            'end_index': 2214,
#            'id': 48118478737,
#            'lap_index': 20,
#            'max_heartrate': 165.0,
#            'max_speed': 3.2,
#            'moving_time': 386,
#            'name': 'Lap 20',
#            'pace_zone': 2,
#            'resource_state': 2,
#            'split': 20,
#            'start_date': '2025-02-12T18:34:09Z',
#            'start_date_local': '2025-02-12T19:34:09Z',
#            'start_index': 1828,
#            'total_elevation_gain': 9.2},
#           {'activity': {'id': 13610646858,
#                         'resource_state': 1,
#                         'visibility': 'followers_only'},
#            'athlete': {'id': 86360204, 'resource_state': 1},
#            'average_cadence': 87.9,
#            'average_heartrate': 157.6,
#            'average_speed': 2.74,
#            'average_watts': 250.3,
#            'device_watts': True,
#            'distance': 279.27,
#            'elapsed_time': 102,
#            'end_index': 2250,
#            'id': 48118478744,
#            'lap_index': 21,
#            'max_heartrate': 161.0,
#            'max_speed': 3.14,
#            'moving_time': 102,
#            'name': 'Lap 21',
#            'pace_zone': 3,
#            'resource_state': 2,
#            'split': 21,
#            'start_date': '2025-02-12T18:40:36Z',
#            'start_date_local': '2025-02-12T19:40:36Z',
#            'start_index': 2215,
#            'total_elevation_gain': 0.0}],
#  'location_city': None,
#  'location_country': None,
#  'location_state': None,
#  'manual': False,
#  'map': {'id': 'a13610646858',
#          'polyline': 'yg_iHsotLe@a@UM_AcAmA_AWYaAw@MOAOBSNWXYVMDI?]Ma@G[B_@ZmAd@_DJc@x@uBHu@^yAPyA`@{AJy@jAeEPkADKLIHAJDFEPc@D[DKDCPCvB}@p@_@n@QbAe@PEJBFAz@m@h@SJGrBw@ZQFBD@HNTDHBb@r@Z~@Ab@Fn@bAnFJx@R`A@NK^?TNz@l@zET~BTdDF`CAdACb@Ar@?z@HrBB~DGnBKzAEf@Ov@_@xCc@lBcAhGYvBUlAU|@CX]rB_@lBqAhEER?PCLQf@GVa@nAm@dBMj@Qh@Yh@M\\mCrDq@p@kAxASPR[t@w@nBcCz@mANOPYRg@Nq@D?f@sAr@yBXgA\\w@Nw@hBsFh@uBNQP_@PsAn@cDVuBb@kF^_DB{@Hi@LoBJ{CA_DMwDHsAAcAKwBA}@MqBc@cELp@b@jEJrBDxC?j@El@?|@HfCAlABv@?~Aa@tFq@lE{@tEk@lDIz@Mn@Kv@Mb@OhAk@xCi@lBo@hBYn@y@zASn@QX_BnDw@tAKTATOZs@o@aAiAuAuBGOYUOUk@m@k@{@aBoB_EqEACBk@AEc@i@UQKUCMCi@NiA`@mANm@JSNg@P]P_Al@iB|@kD?IGQNoATu@Jo@t@wBMq@]g@s@s@i@c@]e@}@y@e@_@W][QCE',
#          'resource_state': 3,
#          'summary_polyline': 'mo_iHq}tLIa@@S`@eB^kCLk@x@uBHu@^yAPyA`@{AJy@jAeEPkADKLIHAJDFEPc@D[DKDCPCvB}@p@_@n@QbAe@PEJBFA^Y^UfBu@B?x@[ZQLDHNTDHBb@r@Z~@Ab@Fn@bAnFJx@R`A@NK^?TNz@l@zEd@vFLhDAjACb@Ar@?z@HrBBpCG|CKbBE^Ov@_@xCc@lBcAhGYvBUlAU|@CX]rB_@lBqAhEER?PCLQf@GVa@nAm@dBMj@Qh@Yh@M\\mCrDq@p@kAxASPR[t@w@nBcCz@mANOPYRg@Nq@D?f@sAr@yBXgA\\w@Nw@hBsFh@uBNQP_@PsAn@cDVuBb@kF^_DB{@Hi@LoBJ{CA_DMwDHsAAcAKwBA}@MqBIm@QoBGg@Lr@b@jEJrBDxC?j@El@?|@HfCAlABv@?~Aa@tFq@lE{@tEk@lDIz@Mn@Kv@Mb@OhAk@xCi@lBo@hBYn@y@zASn@QX_BnDw@tAKTATOZs@o@aAiAuAuBGOYUOUk@m@k@{@aBoB_EqEACBk@AEc@i@UQOc@Ci@NiA`@mANm@JSNg@P]P_Al@iB|@kD?IGQNoATu@Jo@t@wBMq@a@k@'},
#  'max_heartrate': 173.0,
#  'max_speed': 4.02,
#  'max_watts': 429,
#  'moving_time': 2420,
#  'name': '🗼 Evening Run 🏃🏻\u200d♂️🏃🏻\u200d♀️ (🧡 J-25 & 🗼 J-60)',
#  'perceived_exertion': None,
#  'photo_count': 0,
#  'photos': {'count': 0, 'primary': None},
#  'pr_count': 0,
#  'prefer_perceived_exertion': None,
#  'private': False,
#  'resource_state': 3,
#  'segment_efforts': [{'achievements': [],
#                       'activity': {'id': 13610646858,
#                                    'resource_state': 1,
#                                    'visibility': 'followers_only'},
#                       'athlete': {'id': 86360204, 'resource_state': 1},
#                       'average_cadence': 72.7,
#                       'average_heartrate': 139.0,
#                       'average_watts': 222.9,
#                       'device_watts': True,
#                       'distance': 388.2,
#                       'elapsed_time': 172,
#                       'end_index': 334,
#                       'hidden': False,
#                       'id': 3324828807263771858,
#                       'max_heartrate': 150.0,
#                       'moving_time': 147,
#                       'name': 'Pont de Billancourt',
#                       'pr_rank': None,
#                       'resource_state': 2,
#                       'segment': {'activity_type': 'Run',
#                                   'average_grade': -0.7,
#                                   'city': 'Issy-les-Moulineaux',
#                                   'climb_category': 0,
#                                   'country': 'France',
#                                   'distance': 388.2,
#                                   'elevation_high': 35.0,
#                                   'elevation_low': 28.3,
#                                   'elevation_profile': None,
#                                   'elevation_profiles': None,
#                                   'end_latlng': [48.824258, 2.248919],
#                                   'hazardous': False,
#                                   'id': 23279308,
#                                   'maximum_grade': 3.6,
#                                   'name': 'Pont de Billancourt',
#                                   'private': False,
#                                   'resource_state': 2,
#                                   'starred': False,
#                                   'start_latlng': [48.826298, 2.244979],
#                                   'state': 'Île-de-France'},
#                       'start_date': '2025-02-12T18:04:37Z',
#                       'start_date_local': '2025-02-12T19:04:37Z',
#                       'start_index': 186,
#                       'visibility': 'followers_only'},
#                      {'achievements': [],
#                       'activity': {'id': 13610646858,
#                                    'resource_state': 1,
#                                    'visibility': 'followers_only'},
#                       'athlete': {'id': 86360204, 'resource_state': 1},
#                       'average_cadence': 74.6,
#                       'average_heartrate': 139.7,
#                       'average_watts': 221.6,
#                       'device_watts': True,
#                       'distance': 441.7,
#                       'elapsed_time': 197,
#                       'end_index': 382,
#                       'hidden': False,
#                       'id': 3324828807264277714,
#                       'max_heartrate': 150.0,
#                       'moving_time': 172,
#                       'name': 'Rue Jean Pierre Timbaud Climb',
#                       'pr_rank': None,
#                       'resource_state': 2,
#                       'segment': {'activity_type': 'Run',
#                                   'average_grade': 10.2,
#                                   'city': 'Boulogne Billancourt',
#                                   'climb_category': 0,
#                                   'country': 'France',
#                                   'distance': 441.7,
#                                   'elevation_high': 138.4,
#                                   'elevation_low': 93.2,
#                                   'elevation_profile': None,
#                                   'elevation_profiles': None,
#                                   'end_latlng': [48.823044, 2.249122],
#                                   'hazardous': False,
#                                   'id': 6457279,
#                                   'maximum_grade': 21.5,
#                                   'name': 'Rue Jean Pierre Timbaud Climb',
#                                   'private': False,
#                                   'resource_state': 2,
#                                   'starred': False,
#                                   'start_latlng': [48.825968, 2.245611],
#                                   'state': 'IDF'},
#                       'start_date': '2025-02-12T18:05:00Z',
#                       'start_date_local': '2025-02-12T19:05:00Z',
#                       'start_index': 209,
#                       'visibility': 'followers_only'},
#                      {'achievements': [{'rank': 2, 'type': 'pr', 'type_id': 3}],
#                       'activity': {'id': 13610646858,
#                                    'resource_state': 1,
#                                    'visibility': 'followers_only'},
#                       'athlete': {'id': 86360204, 'resource_state': 1},
#                       'average_cadence': 87.6,
#                       'average_heartrate': 146.9,
#                       'average_watts': 245.1,
#                       'device_watts': True,
#                       'distance': 1621.5,
#                       'elapsed_time': 601,
#                       'end_index': 1030,
#                       'hidden': False,
#                       'id': 3324828807261700306,
#                       'max_heartrate': 173.0,
#                       'moving_time': 601,
#                       'name': "Pont d'Issy - La Seine Musicale",
#                       'pr_rank': 2,
#                       'resource_state': 2,
#                       'segment': {'activity_type': 'Run',
#                                   'average_grade': 0.2,
#                                   'city': 'Issy-les-Moulineaux',
#                                   'climb_category': 0,
#                                   'country': 'France',
#                                   'distance': 1621.5,
#                                   'elevation_high': 50.1,
#                                   'elevation_low': 29.0,
#                                   'elevation_profile': None,
#                                   'elevation_profiles': None,
#                                   'end_latlng': [48.823695, 2.230111],
#                                   'hazardous': False,
#                                   'id': 15750370,
#                                   'maximum_grade': 39.4,
#                                   'name': "Pont d'Issy - La Seine Musicale",
#                                   'private': False,
#                                   'resource_state': 2,
#                                   'starred': False,
#                                   'start_latlng': [48.822014, 2.24977],
#                                   'state': 'Île-de-France'},
#                       'start_date': '2025-02-12T18:09:04Z',
#                       'start_date_local': '2025-02-12T19:09:04Z',
#                       'start_index': 429,
#                       'visibility': 'followers_only'},
#                      {'achievements': [],
#                       'activity': {'id': 13610646858,
#                                    'resource_state': 1,
#                                    'visibility': 'followers_only'},
#                       'athlete': {'id': 86360204, 'resource_state': 1},
#                       'average_cadence': 87.4,
#                       'average_heartrate': 144.6,
#                       'average_watts': 237.7,
#                       'device_watts': True,
#                       'distance': 1004.4,
#                       'elapsed_time': 373,
#                       'end_index': 815,
#                       'hidden': False,
#                       'id': 3324828807263134930,
#                       'max_heartrate': 152.0,
#                       'moving_time': 373,
#                       'name': '1000m Stalingrad',
#                       'pr_rank': None,
#                       'resource_state': 2,
#                       'segment': {'activity_type': 'Run',
#                                   'average_grade': -0.1,
#                                   'city': 'Meudon',
#                                   'climb_category': 0,
#                                   'country': 'France',
#                                   'distance': 1004.4,
#                                   'elevation_high': 35.1,
#                                   'elevation_low': 32.7,
#                                   'elevation_profile': None,
#                                   'elevation_profiles': None,
#                                   'end_latlng': [48.82056, 2.236823],
#                                   'hazardous': False,
#                                   'id': 25643289,
#                                   'maximum_grade': 0.9,
#                                   'name': '1000m Stalingrad',
#                                   'private': False,
#                                   'resource_state': 2,
#                                   'starred': False,
#                                   'start_latlng': [48.8218, 2.249655],
#                                   'state': 'Île-de-France'},
#                       'start_date': '2025-02-12T18:09:17Z',
#                       'start_date_local': '2025-02-12T19:09:17Z',
#                       'start_index': 442,
#                       'visibility': 'followers_only'},
#                      {'achievements': [],
#                       'activity': {'id': 13610646858,
#                                    'resource_state': 1,
#                                    'visibility': 'followers_only'},
#                       'athlete': {'id': 86360204, 'resource_state': 1},
#                       'average_cadence': 87.5,
#                       'average_heartrate': 146.0,
#                       'average_watts': 238.7,
#                       'device_watts': True,
#                       'distance': 299.6,
#                       'elapsed_time': 110,
#                       'end_index': 658,
#                       'hidden': False,
#                       'id': 3324828807263072466,
#                       'max_heartrate': 152.0,
#                       'moving_time': 110,
#                       'name': 'sprint 300m Stalingrad',
#                       'pr_rank': None,
#                       'resource_state': 2,
#                       'segment': {'activity_type': 'Run',
#                                   'average_grade': -0.1,
#                                   'city': 'Issy-les-Moulineaux',
#                                   'climb_category': 0,
#                                   'country': 'France',
#                                   'distance': 299.6,
#                                   'elevation_high': 29.6,
#                                   'elevation_low': 28.4,
#                                   'elevation_profile': None,
#                                   'elevation_profiles': None,
#                                   'end_latlng': [48.820228, 2.242621],
#                                   'hazardous': False,
#                                   'id': 33391428,
#                                   'maximum_grade': 1.4,
#                                   'name': 'sprint 300m Stalingrad',
#                                   'private': False,
#                                   'resource_state': 2,
#                                   'starred': False,
#                                   'start_latlng': [48.820839, 2.246554],
#                                   'state': 'Île-de-France'},
#                       'start_date': '2025-02-12T18:11:03Z',
#                       'start_date_local': '2025-02-12T19:11:03Z',
#                       'start_index': 548,
#                       'visibility': 'followers_only'},
#                      {'achievements': [],
#                       'activity': {'id': 13610646858,
#                                    'resource_state': 1,
#                                    'visibility': 'followers_only'},
#                       'athlete': {'id': 86360204, 'resource_state': 1},
#                       'average_cadence': 87.5,
#                       'average_heartrate': 145.4,
#                       'average_watts': 240.1,
#                       'device_watts': True,
#                       'distance': 818.7,
#                       'elapsed_time': 303,
#                       'end_index': 920,
#                       'hidden': False,
#                       'id': 3324828807261283538,
#                       'max_heartrate': 149.0,
#                       'moving_time': 303,
#                       'name': '800m Halage E-W',
#                       'pr_rank': None,
#                       'resource_state': 2,
#                       'segment': {'activity_type': 'Run',
#                                   'average_grade': -0.3,
#                                   'city': 'Issy-les-Moulineaux',
#                                   'climb_category': 0,
#                                   'country': 'France',
#                                   'distance': 818.7,
#                                   'elevation_high': 34.0,
#                                   'elevation_low': 31.1,
#                                   'elevation_profile': None,
#                                   'elevation_profiles': None,
#                                   'end_latlng': [48.821802, 2.233525],
#                                   'hazardous': False,
#                                   'id': 32817214,
#                                   'maximum_grade': 1.5,
#                                   'name': '800m Halage E-W',
#                                   'private': False,
#                                   'resource_state': 2,
#                                   'starred': False,
#                                   'start_latlng': [48.820298, 2.244128],
#                                   'state': 'Île-de-France'},
#                       'start_date': '2025-02-12T18:12:12Z',
#                       'start_date_local': '2025-02-12T19:12:12Z',
#                       'start_index': 617,
#                       'visibility': 'followers_only'},
#                      {'achievements': [],
#                       'activity': {'id': 13610646858,
#                                    'resource_state': 1,
#                                    'visibility': 'followers_only'},
#                       'athlete': {'id': 86360204, 'resource_state': 1},
#                       'average_cadence': 86.0,
#                       'average_heartrate': 153.8,
#                       'average_watts': 260.8,
#                       'device_watts': True,
#                       'distance': 485.8,
#                       'elapsed_time': 168,
#                       'end_index': 1036,
#                       'hidden': False,
#                       'id': 3324828807262112978,
#                       'max_heartrate': 173.0,
#                       'moving_time': 168,
#                       'name': 'Old bridge to new bridge ',
#                       'pr_rank': None,
#                       'resource_state': 2,
#                       'segment': {'activity_type': 'Run',
#                                   'average_grade': 0.3,
#                                   'city': 'Meudon',
#                                   'climb_category': 0,
#                                   'country': 'France',
#                                   'distance': 485.8,
#                                   'elevation_high': 48.4,
#                                   'elevation_low': 44.8,
#                                   'elevation_profile': None,
#                                   'elevation_profiles': None,
#                                   'end_latlng': [48.823865, 2.230043],
#                                   'hazardous': False,
#                                   'id': 17374812,
#                                   'maximum_grade': 6.3,
#                                   'name': 'Old bridge to new bridge ',
#                                   'private': False,
#                                   'resource_state': 2,
#                                   'starred': False,
#                                   'start_latlng': [48.821336, 2.235314],
#                                   'state': 'Île-de-France'},
#                       'start_date': '2025-02-12T18:16:23Z',
#                       'start_date_local': '2025-02-12T19:16:23Z',
#                       'start_index': 868,
#                       'visibility': 'followers_only'},
#                      {'achievements': [],
#                       'activity': {'id': 13610646858,
#                                    'resource_state': 1,
#                                    'visibility': 'followers_only'},
#                       'athlete': {'id': 86360204, 'resource_state': 1},
#                       'average_cadence': 84.1,
#                       'average_heartrate': 161.6,
#                       'average_watts': 259.6,
#                       'device_watts': True,
#                       'distance': 1001.9,
#                       'elapsed_time': 343,
#                       'end_index': 1464,
#                       'hidden': False,
#                       'id': 3324828807262209234,
#                       'max_heartrate': 168.0,
#                       'moving_time': 342,
#                       'name': '1000 CHALLENGE TRC ',
#                       'pr_rank': None,
#                       'resource_state': 2,
#                       'segment': {'activity_type': 'Run',
#                                   'average_grade': -0.1,
#                                   'city': 'Sèvres',
#                                   'climb_category': 0,
#                                   'country': 'France',
#                                   'distance': 1001.9,
#                                   'elevation_high': 32.5,
#                                   'elevation_low': 30.8,
#                                   'elevation_profile': None,
#                                   'elevation_profiles': None,
#                                   'end_latlng': [48.820284, 2.241975],
#                                   'hazardous': False,
#                                   'id': 23950168,
#                                   'maximum_grade': 0.6,
#                                   'name': '1000 CHALLENGE TRC ',
#                                   'private': False,
#                                   'resource_state': 2,
#                                   'starred': False,
#                                   'start_latlng': [48.823689, 2.229795],
#                                   'state': 'Île-de-France'},
#                       'start_date': '2025-02-12T18:20:36Z',
#                       'start_date_local': '2025-02-12T19:20:36Z',
#                       'start_index': 1121,
#                       'visibility': 'followers_only'},
#                      {'achievements': [],
#                       'activity': {'id': 13610646858,
#                                    'resource_state': 1,
#                                    'visibility': 'followers_only'},
#                       'athlete': {'id': 86360204, 'resource_state': 1},
#                       'average_cadence': 83.7,
#                       'average_heartrate': 161.9,
#                       'average_watts': 260.0,
#                       'device_watts': True,
#                       'distance': 423.4,
#                       'elapsed_time': 145,
#                       'end_index': 1278,
#                       'hidden': False,
#                       'id': 3324828807262535890,
#                       'max_heartrate': 167.0,
#                       'moving_time': 144,
#                       'name': '400m New bridge to Old bridge',
#                       'pr_rank': None,
#                       'resource_state': 2,
#                       'segment': {'activity_type': 'Run',
#                                   'average_grade': -0.3,
#                                   'city': 'Sèvres',
#                                   'climb_category': 0,
#                                   'country': 'France',
#                                   'distance': 423.4,
#                                   'elevation_high': 34.6,
#                                   'elevation_low': 32.2,
#                                   'elevation_profile': None,
#                                   'elevation_profiles': None,
#                                   'end_latlng': [48.821394, 2.235004],
#                                   'hazardous': False,
#                                   'id': 15938625,
#                                   'maximum_grade': 2.4,
#                                   'name': '400m New bridge to Old bridge',
#                                   'private': False,
#                                   'resource_state': 2,
#                                   'starred': False,
#                                   'start_latlng': [48.823581, 2.230343],
#                                   'state': 'Île-de-France'},
#                       'start_date': '2025-02-12T18:20:48Z',
#                       'start_date_local': '2025-02-12T19:20:48Z',
#                       'start_index': 1133,
#                       'visibility': 'followers_only'},
#                      {'achievements': [{'rank': 3, 'type': 'pr', 'type_id': 3}],
#                       'activity': {'id': 13610646858,
#                                    'resource_state': 1,
#                                    'visibility': 'followers_only'},
#                       'athlete': {'id': 86360204, 'resource_state': 1},
#                       'average_cadence': 84.3,
#                       'average_heartrate': 160.9,
#                       'average_watts': 260.6,
#                       'device_watts': True,
#                       'distance': 1089.5,
# ...
#                      {'achievements': [],
#                       'activity': {'id': 13610646858,
#                                    'resource_state': 1,
#                                    'visibility': 'followers_only'},
#                       'athlete': {'id': 86360204, 'resource_state': 1},
#                       'average_cadence': 87.9,
#                       'average_heartrate': 162.7,
#                       'average_watts': 265.2,
#                       'device_watts': True,
#                       'distance': 818.7,
#                       'elapsed_time': 265,
#                       'end_index': 1858,
#                       'hidden': False,
#                       'id': 3324828807261657298,
#                       'max_heartrate': 170.0,
#                       'moving_time': 265,
#                       'name': '800m Halage E-W',
#                       'pr_rank': None,
#                       'resource_state': 2,
#                       'segment': {'activity_type': 'Run',
#                                   'average_grade': -0.3,
#                                   'city': 'Issy-les-Moulineaux',
#                                   'climb_category': 0,
#                                   'country': 'France',
#                                   'distance': 818.7,
#                                   'elevation_high': 34.0,
#                                   'elevation_low': 31.1,
#                                   'elevation_profile': None,
#                                   'elevation_profiles': None,
#                                   'end_latlng': [48.821802, 2.233525],
#                                   'hazardous': False,
#                                   'id': 32817214,
#                                   'maximum_grade': 1.5,
#                                   'name': '800m Halage E-W',
#                                   'private': False,
#                                   'resource_state': 2,
#                                   'starred': False,
#                                   'start_latlng': [48.820298, 2.244128],
#                                   'state': 'Île-de-France'},
#                       'start_date': '2025-02-12T18:28:28Z',
#                       'start_date_local': '2025-02-12T19:28:28Z',
#                       'start_index': 1593,
#                       'visibility': 'followers_only'},
#                      {'achievements': [],
#                       'activity': {'id': 13610646858,
#                                    'resource_state': 1,
#                                    'visibility': 'followers_only'},
#                       'athlete': {'id': 86360204, 'resource_state': 1},
#                       'average_cadence': 82.3,
#                       'average_heartrate': 160.7,
#                       'average_watts': 245.9,
#                       'device_watts': True,
#                       'distance': 485.8,
#                       'elapsed_time': 178,
#                       'end_index': 1994,
#                       'hidden': False,
#                       'id': 3324828807262661842,
#                       'max_heartrate': 170.0,
#                       'moving_time': 176,
#                       'name': 'Old bridge to new bridge ',
#                       'pr_rank': None,
#                       'resource_state': 2,
#                       'segment': {'activity_type': 'Run',
#                                   'average_grade': 0.3,
#                                   'city': 'Meudon',
#                                   'climb_category': 0,
#                                   'country': 'France',
#                                   'distance': 485.8,
#                                   'elevation_high': 48.4,
#                                   'elevation_low': 44.8,
#                                   'elevation_profile': None,
#                                   'elevation_profiles': None,
#                                   'end_latlng': [48.823865, 2.230043],
#                                   'hazardous': False,
#                                   'id': 17374812,
#                                   'maximum_grade': 6.3,
#                                   'name': 'Old bridge to new bridge ',
#                                   'private': False,
#                                   'resource_state': 2,
#                                   'starred': False,
#                                   'start_latlng': [48.821336, 2.235314],
#                                   'state': 'Île-de-France'},
#                       'start_date': '2025-02-12T18:32:11Z',
#                       'start_date_local': '2025-02-12T19:32:11Z',
#                       'start_index': 1816,
#                       'visibility': 'followers_only'},
#                      {'achievements': [],
#                       'activity': {'id': 13610646858,
#                                    'resource_state': 1,
#                                    'visibility': 'followers_only'},
#                       'athlete': {'id': 86360204, 'resource_state': 1},
#                       'average_cadence': 87.7,
#                       'average_heartrate': 157.6,
#                       'average_watts': 264.3,
#                       'device_watts': True,
#                       'distance': 468.9,
#                       'elapsed_time': 159,
#                       'end_index': 2150,
#                       'hidden': False,
#                       'id': 3324828807260900562,
#                       'max_heartrate': 165.0,
#                       'moving_time': 159,
#                       'name': 'Pont Renault vers Boulogne',
#                       'pr_rank': None,
#                       'resource_state': 2,
#                       'segment': {'activity_type': 'Run',
#                                   'average_grade': -0.2,
#                                   'city': None,
#                                   'climb_category': 0,
#                                   'country': None,
#                                   'distance': 468.9,
#                                   'elevation_high': 40.0,
#                                   'elevation_low': 24.4,
#                                   'elevation_profile': None,
#                                   'elevation_profiles': None,
#                                   'end_latlng': [48.826798, 2.233682],
#                                   'hazardous': False,
#                                   'id': 15751545,
#                                   'maximum_grade': 32.7,
#                                   'name': 'Pont Renault vers Boulogne',
#                                   'private': False,
#                                   'resource_state': 2,
#                                   'starred': False,
#                                   'start_latlng': [48.82374, 2.230099],
#                                   'state': None},
#                       'start_date': '2025-02-12T18:35:06Z',
#                       'start_date_local': '2025-02-12T19:35:06Z',
#                       'start_index': 1991,
#                       'visibility': 'followers_only'},
#                      {'achievements': [],
#                       'activity': {'id': 13610646858,
#                                    'resource_state': 1,
#                                    'visibility': 'followers_only'},
#                       'athlete': {'id': 86360204, 'resource_state': 1},
#                       'average_cadence': 89.1,
#                       'average_heartrate': 155.4,
#                       'average_watts': 208.6,
#                       'device_watts': True,
#                       'distance': 117.6,
#                       'elapsed_time': 36,
#                       'end_index': 2154,
#                       'hidden': False,
#                       'id': 3324828807262752978,
#                       'max_heartrate': 158.0,
#                       'moving_time': 36,
#                       'name': 'Cote vers l’île Seguin ',
#                       'pr_rank': None,
#                       'resource_state': 2,
#                       'segment': {'activity_type': 'Run',
#                                   'average_grade': -5.8,
#                                   'city': 'Boulogne-Billancourt',
#                                   'climb_category': 0,
#                                   'country': 'France',
#                                   'distance': 117.6,
#                                   'elevation_high': 29.0,
#                                   'elevation_low': 22.0,
#                                   'elevation_profile': None,
#                                   'elevation_profiles': None,
#                                   'end_latlng': [48.826997, 2.233855],
#                                   'hazardous': False,
#                                   'id': 23680199,
#                                   'maximum_grade': 1.9,
#                                   'name': 'Cote vers l’île Seguin ',
#                                   'private': False,
#                                   'resource_state': 2,
#                                   'starred': False,
#                                   'start_latlng': [48.826099, 2.23302],
#                                   'state': 'Île-de-France'},
#                       'start_date': '2025-02-12T18:37:13Z',
#                       'start_date_local': '2025-02-12T19:37:13Z',
#                       'start_index': 2118,
#                       'visibility': 'followers_only'}],
#  'similar_activities': {'average_speed': 2.6583978176186522,
#                         'effort_count': 5,
#                         'frequency_milestone': 5,
#                         'max_average_speed': 2.807687014423909,
#                         'mid_average_speed': 2.6752153277325603,
#                         'min_average_speed': 2.5546809203235816,
#                         'pr_rank': 2,
#                         'resource_state': 2,
#                         'trend': {'current_activity_index': 4,
#                                   'direction': 1,
#                                   'max_speed': 2.807687014423909,
#                                   'mid_speed': 2.6752153277325603,
#                                   'min_speed': 2.5546809203235816,
#                                   'speeds': [2.6009993988382747,
#                                              2.7003940249654916,
#                                              2.650865194699185,
#                                              2.6261464530181673,
#                                              2.6695719751204283]}},
#  'splits_metric': [{'average_grade_adjusted_speed': 2.72,
#                     'average_heartrate': 134.76861702127658,
#                     'average_speed': 2.67,
#                     'distance': 1002.4,
#                     'elapsed_time': 401,
#                     'elevation_difference': 5.0,
#                     'moving_time': 376,
#                     'pace_zone': 3,
#                     'split': 1},
#                    {'average_grade_adjusted_speed': 2.66,
#                     'average_heartrate': 143.77358490566039,
#                     'average_speed': 2.69,
#                     'distance': 998.7,
#                     'elapsed_time': 371,
#                     'elevation_difference': -6.2,
#                     'moving_time': 371,
#                     'pace_zone': 2,
#                     'split': 2},
#                    {'average_grade_adjusted_speed': 2.83,
#                     'average_heartrate': 152.10614525139664,
#                     'average_speed': 2.8,
#                     'distance': 1001.8,
#                     'elapsed_time': 358,
#                     'elevation_difference': 2.8,
#                     'moving_time': 358,
#                     'pace_zone': 3,
#                     'split': 3},
#                    {'average_grade_adjusted_speed': 2.94,
#                     'average_heartrate': 162.06489675516224,
#                     'average_speed': 2.94,
#                     'distance': 999.2,
#                     'elapsed_time': 340,
#                     'elevation_difference': -0.6,
#                     'moving_time': 340,
#                     'pace_zone': 3,
#                     'split': 4},
#                    {'average_grade_adjusted_speed': 2.98,
#                     'average_heartrate': 161.42342342342343,
#                     'average_speed': 2.99,
#                     'distance': 999.5,
#                     'elapsed_time': 334,
#                     'elevation_difference': -3.4,
#                     'moving_time': 334,
#                     'pace_zone': 3,
#                     'split': 5},
#                    {'average_grade_adjusted_speed': 2.8,
#                     'average_heartrate': 159.38858695652175,
#                     'average_speed': 2.7,
#                     'distance': 1000.2,
#                     'elapsed_time': 370,
#                     'elevation_difference': 3.0,
#                     'moving_time': 370,
#                     'pace_zone': 3,
#                     'split': 6},
#                    {'average_grade_adjusted_speed': 2.68,
#                     'average_heartrate': 154.7389705882353,
#                     'average_speed': 2.67,
#                     'distance': 726.2,
#                     'elapsed_time': 272,
#                     'elevation_difference': 0.6,
#                     'moving_time': 272,
#                     'pace_zone': 2,
#                     'split': 7}],
#  'splits_standard': [{'average_grade_adjusted_speed': 2.69,
#                       'average_heartrate': 137.85406301824213,
#                       'average_speed': 2.67,
#                       'distance': 1610.9,
#                       'elapsed_time': 628,
#                       'elevation_difference': 0.0,
#                       'moving_time': 603,
#                       'pace_zone': 2,
#                       'split': 1},
#                      {'average_grade_adjusted_speed': 2.82,
#                       'average_heartrate': 151.94589877835952,
#                       'average_speed': 2.8,
#                       'distance': 1609.7,
#                       'elapsed_time': 574,
#                       'elevation_difference': 1.6,
#                       'moving_time': 574,
#                       'pace_zone': 3,
#                       'split': 2},
#                      {'average_grade_adjusted_speed': 2.94,
#                       'average_heartrate': 160.90275229357798,
#                       'average_speed': 2.95,
#                       'distance': 1610.1,
#                       'elapsed_time': 546,
#                       'elevation_difference': -2.6,
#                       'moving_time': 546,
#                       'pace_zone': 3,
#                       'split': 3},
#                      {'average_grade_adjusted_speed': 2.77,
#                       'average_heartrate': 158.17118644067796,
#                       'average_speed': 2.72,
#                       'distance': 1608.1,
#                       'elapsed_time': 592,
#                       'elevation_difference': 1.2,
#                       'moving_time': 592,
#                       'pace_zone': 3,
#                       'split': 4},
#                      {'average_grade_adjusted_speed': 2.76,
#                       'average_heartrate': 157.5566037735849,
#                       'average_speed': 2.73,
#                       'distance': 289.2,
#                       'elapsed_time': 106,
#                       'elevation_difference': 1.0,
#                       'moving_time': 106,
#                       'pace_zone': 3,
#                       'split': 5}],
#  'sport_type': 'Run',
#  'start_date': '2025-02-12T18:01:31Z',
#  'start_date_local': '2025-02-12T19:01:31Z',
#  'start_latlng': [48.825737, 2.2401],
#  'stats_visibility': [{'type': 'heart_rate', 'visibility': 'everyone'},
#                       {'type': 'pace', 'visibility': 'everyone'},
#                       {'type': 'power', 'visibility': 'everyone'},
#                       {'type': 'speed', 'visibility': 'everyone'},
#                       {'type': 'calories', 'visibility': 'everyone'}],
#  'timezone': '(GMT+01:00) Europe/Paris',
#  'total_elevation_gain': 22.0,
#  'total_photo_count': 0,
#  'trainer': False,
#  'type': 'Run',
#  'upload_id': 14522249842,
#  'upload_id_str': '14522249842',
#  'utc_offset': 3600.0,
#  'visibility': 'followers_only',
#  'weighted_average_watts': 249,
#  'workout_type': None}

# %%
import requests

ACCESS_TOKEN = "79f3c343cf1dd482f3843540649416ebb4bf70cd"

url = "https://www.strava.com/api/v3/athlete"
headers = {"Authorization": f"Bearer {ACCESS_TOKEN}"}

response = requests.get(url, headers=headers)

if response.status_code == 200:
    print("✅ Ton access_token est valide !")
    print(response.json())  # Affiche les infos de ton compte
else:
    print("❌ Erreur :", response.json())  # Vérifie si ton scope est suffisant
# Out:
# ✅ Ton access_token est valide !
# {'id': 86360204, 'username': 'elancelle', 'resource_state': 2, 'firstname': 'Etienne', 'lastname': 'Lancelle', 'bio': '➡️ Semi-marathon de Paris (09/03)  \n10K (x4) : 54’54’’  \n21K (x3) : 1:59’00’’  \n42K : ?', 'city': 'Boulogne-Billancourt', 'state': None, 'country': None, 'sex': 'M', 'premium': False, 'summit': False, 'created_at': '2021-05-31T15:22:52Z', 'updated_at': '2025-02-02T15:21:04Z', 'badge_type_id': 0, 'weight': 65.0, 'profile_medium': 'https://dgalywyr863hv.cloudfront.net/pictures/athletes/86360204/33884293/1/medium.jpg', 'profile': 'https://dgalywyr863hv.cloudfront.net/pictures/athletes/86360204/33884293/1/large.jpg', 'friend': None, 'follower': None}

# %%
secrets.get('STRAVA_CLIENT_ID')
callback = 'http://localhost:5000/callback'

# %%
f"https://www.strava.com/oauth/authorize?client_id={secrets.get('STRAVA_CLIENT_ID')
}&redirect_uri={callback}&response_type=code&scope=activity:read_all&approval_prompt=force"
# Out:
# 'https://www.strava.com/oauth/authorize?client_id=127031&redirect_uri=http://localhost:5000/callback&response_type=code&scope=activity:read_all&approval_prompt=force'

# %%
http://localhost:5000/callback?state=&code=2f45e57ede72d174e9dc2172ebcc6b28d8ad1f22&scope=read,activity:read_all

# %%
import requests

ACCESS_TOKEN = secrets.get('STRAVA_ACCESS_TOKEN')

url = "https://www.strava.com/api/v3/athlete"
headers = {"Authorization": f"Bearer {ACCESS_TOKEN}"}

response = requests.get(url, headers=headers)

if response.status_code == 200:
    print("✅ Ton access_token est valide !")
    print(response.json())  # Affiche les infos de ton compte
else:
    print("❌ Erreur :", response.json())  # Vérifie si ton scope est suffisant
# Out:
# ❌ Erreur : {'message': 'Authorization Error', 'errors': [{'resource': 'Athlete', 'field': 'access_token', 'code': 'invalid'}]}

# %%
f"https://www.strava.com/oauth/authorize?client_id={secrets.get('STRAVA_CLIENT_ID')}&redirect_uri={callback}&response_type=code&scope=activity:read_all&approval_prompt=force"
# Out:
# 'https://www.strava.com/oauth/authorize?client_id=127031&redirect_uri=http://localhost:5000/callback&response_type=code&scope=activity:read_all&approval_prompt=force'

# %%
http://localhost:5000/callback?state=&code=8866f64d415954334e9e998092a5a1e5f41dedbb&scope=read,activity:read_all

# %%
secrets
# Out:
# OrderedDict([('STRAVA_REFRESH_TOKEN',
#               '0125eaf0ccf6a09cb538eccfea341e9219206a2e'),
#              ('STRAVA_CLIENT_ID', '127031'),
#              ('STRAVA_SECRET', '641f9f581fc9ce96833f6d863361f447fd2e2ac0')])

# %%
import requests

CLIENT_ID = secrets.get('STRAVA_CLIENT_ID')
CLIENT_SECRET = secrets.get('STRAVA_SECRET')
CODE = "8866f64d415954334e9e998092a5a1e5f41dedbb"

url = "https://www.strava.com/oauth/token"
params = {
    "client_id": CLIENT_ID,
    "client_secret": CLIENT_SECRET,
    "code": CODE,
    "grant_type": "authorization_code",
}

response = requests.post(url, data=params)
tokens = response.json()

if "access_token" in tokens:
    print("✅ Nouveau jeton d'accès récupéré !")
    print("Access Token:", tokens["access_token"])
    print("Scopes autorisés :", tokens)
else:
    print("❌ Erreur :", tokens)
# Out:
# ✅ Nouveau jeton d'accès récupéré !
# Access Token: 79f3c343cf1dd482f3843540649416ebb4bf70cd
# Scopes autorisés : {'token_type': 'Bearer', 'expires_at': 1739647687, 'expires_in': 8364, 'refresh_token': 'e4c6dab4ad00d26aaf19712d22a1006210ac3ef2', 'access_token': '79f3c343cf1dd482f3843540649416ebb4bf70cd', 'athlete': {'id': 86360204, 'username': 'elancelle', 'resource_state': 2, 'firstname': 'Etienne', 'lastname': 'Lancelle', 'bio': '➡️ Semi-marathon de Paris (09/03)  \n10K (x4) : 54’54’’  \n21K (x3) : 1:59’00’’  \n42K : ?', 'city': 'Boulogne-Billancourt', 'state': None, 'country': None, 'sex': 'M', 'premium': False, 'summit': False, 'created_at': '2021-05-31T15:22:52Z', 'updated_at': '2025-02-02T15:21:04Z', 'badge_type_id': 0, 'weight': 65.0, 'profile_medium': 'https://dgalywyr863hv.cloudfront.net/pictures/athletes/86360204/33884293/1/medium.jpg', 'profile': 'https://dgalywyr863hv.cloudfront.net/pictures/athletes/86360204/33884293/1/large.jpg', 'friend': None, 'follower': None}}

# %%
datetime.datetime.strftime('2025-01-01', '%Y-%m-%d')
